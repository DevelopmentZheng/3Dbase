# %% [markdown]
# <a href="https://colab.research.google.com/github/DevelopmentZheng/3Dbase/blob/main/001piontCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #点云

# %% [markdown]
# 呈现图片

# %% [markdown]
# ## 来源
# 一般来自雷达的采集，比如自动驾驶的车辆上就会装置很多雷达，我们还可以把2d图像数据通过深度学习转成3d数据，形成伪点云。

# %% [markdown]
# ![截屏2023-05-11 下午9.17.55.png](data:image/png;base64,...)

# %% [markdown]
# 我们可以通过nucense数据集来了解点云

# %% [markdown]
# ## nucense
# https://www.nuscenes.org/nuscenes

# %% [markdown]
# ## 了解数据集
# 这个数据集由上图的多个传感器采集而来

# %%
n
